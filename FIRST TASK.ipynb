# %%
#importing libraries that we use to perform on the data of EDA process

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/eswar/Downloads/archive (1)/study_performance.csv")

# %%
#1 UNDERSTANDIND THE DATA

# %%
data.head() #it is for first five rows under the columns of the data set
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.tail()  #it is for last five rows under the columns of the data set
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.shape #to know how many rows and colums in the data
# Out:
# (1000, 8)

# %%
#so we get to know that there are 1000 entries in  the data set and necessary colums of the data set

# %%
data.describe() #It provides a summary of statistical measures for the numerical columns in the dataset
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.columns  #It shows the colums that are present in our dataset
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
data.nunique() #It gives the unique values that every variable or column has
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %%
data['gender'].unique()  #it gives the unique values of  a particular variable or column
# Out:
# array(['female', 'male'], dtype=object)

# %%
data['race_ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
data['parental_level_of_education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
data['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
data['test_preparation_course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
'''by looking at this values we understand that we have categorical values like lunch , test_preparation_course''' 
#so the important variables in the dataset are (  math_score, reading_score , writing_score )  
'''race_ethnicity  , parental_level_of_education these two can be droppen from the data by understanding the data 
(these are not much important for the dataset )'''

# %%
# cleaning the data

# %%
data.isnull().sum()  #to know the null values in our data set and it sum of each column
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
#so in our data set there are no null values

# %%
study_performance = data.drop(['race_ethnicity','parental_level_of_education'],axis = 1) #to drop the unecessary data or reduntant variables

# %%
study_performance.head()
# Out:
#    gender         lunch test_preparation_course  math_score  reading_score  \
# 0  female      standard                    none          72             72
# 1  female      standard               completed          69             90
# 2  female      standard                    none          90             95
# 3    male  free/reduced                    none          47             57
# 4    male      standard                    none          76             78
#
#    writing_score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75

# %%
#since there are no null values in this dataset we are neglecting "outliers"

# %%
'''RELATIONSHIP BETWEEN VARIABLES'''

# %%
correlation = study_performance.drop(columns=['gender','lunch','test_preparation_course']).corr()

# %%
sns.heatmap(correlation,xticklabels = correlation.columns,yticklabels = correlation.columns,annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(study_performance) #to visualize the relationship between any two variables

# %%
sns.relplot(x = 'math_score' , y ='reading_score' , hue = 'lunch' , data = study_performance) #scatterplot
'''to get the relationship between two numerical values'''
# Out:
# 'to get the relationship between two numerical values'

# %%
'''Histogram it is a graphical representation of data using bars of diferent heights'''

# %%
sns.displot(study_performance['math_score'],bins = 6)   #to get the relation of variables by graphical representation

# %%
sns.displot(study_performance['reading_score'],bins = 6)
